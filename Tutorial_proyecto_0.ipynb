# %% [markdown]
# <a href="https://colab.research.google.com/github/kaaryFigueroa/ML-tutorial/blob/main/Tutorial_proyecto_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %% [markdown]
# y = 4 + 3 * X_1 + ruidoGaussiano

# %%
import matplotlib.pyplot as plt
plt.plot(X, y, "b.")
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
#ecuación normal
X_b = np.c_[np.ones((100, 1)), X]  # add x0 = 1 to each instance
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best
#Pendiente y abcisa  a X_0 + b X_1
# Out:
# array([[4.02038801],
#        [2.88779299]])

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]  # add x0 = 1 to each instance
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[4.02038801],
#        [9.79597399]])

# %%
#graficamos esos 2 puntos
plt.plot(X_new, y_predict, "r-", linewidth=2, label="Predictions")
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# # Comprobamos con la librería de sklearn

# %%
from sklearn.linear_model import LinearRegression
#usa least squares
lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([3.99326498]), array([[3.16279001]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[4.02038801],
#        [9.79597399]])
